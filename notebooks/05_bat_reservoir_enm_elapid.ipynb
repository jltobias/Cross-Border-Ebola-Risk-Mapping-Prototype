# %% [markdown]
# # Bat reservoir ENM with elapid
#
# Prepare presence/background samples and fit an elapid Maxent model for reservoir/interface suitability.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## ENM design
#
# Use bat occurrence or roost points as presences and environmentally plausible background points. Avoid using all human case locations as pure ecological presences because human-to-human transmission, surveillance, funerals, and health-care exposure affect case locations.

# %%
from cberm.enm import prepare_presence_background
# presences = pd.read_parquet(paths.data_processed / "bat_presence_covariates.parquet")
# background = pd.read_parquet(paths.data_processed / "background_covariates.parquet")
# features = ["elevation", "forest_cover", "forest_edge", "distance_to_water", "rainfall_proxy"]
# train = prepare_presence_background(presences, background, features)
# model = fit_elapid_maxent(train, features)
print("Prepare presence/background tables before fitting elapid Maxent.")
