# %% [markdown]
# # GIS folder data inventory
#
# Inventory local files under GIS/ and classify them into thematic model layers.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## Inventory GIS files
#
# This step does not open the files; it only records file paths, extensions, sizes, and rough thematic classes.

# %%
from cberm.io import discover_gis_files, write_inventory_csv
rows = discover_gis_files(paths.gis_root)
out = paths.data_interim / "layer_inventory.csv"
write_inventory_csv(rows, out)
print(f"Found {len(rows)} files. Wrote {out}")
pd.read_csv(out).head(20) if out.exists() else pd.DataFrame()

# %% [markdown]
# ## Next action
#
# Review `data/interim/layer_inventory.csv` and update `configs/layer_catalog.yml` with confirmed paths and data sensitivity classifications.
