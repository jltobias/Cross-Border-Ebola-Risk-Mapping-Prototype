# %% [markdown]
# # Validation, sensitivity, and export
#
# Validate outputs, inspect driver sensitivity, and export map/table deliverables.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## Validation and export
#
# Use spatial block validation, holdout by admin unit, known affected zones, SME review, and sensitivity analysis. Export GeoTIFF, GeoPackage, CSV, and a short method note.

# %%
# Example export paths:
exports = {
    "facility_table": paths.outputs / "tables/facility_risk_rankings.csv",
    "catchment_gpkg": paths.outputs / "maps/facility_catchment_risk.gpkg",
    "risk_tif": paths.outputs / "maps/combined_risk_1km.tif",
    "uncertainty_tif": paths.outputs / "maps/model_uncertainty_1km.tif",
}
exports
