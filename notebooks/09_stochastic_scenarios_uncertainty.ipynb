# %% [markdown]
# # Stochastic scenarios and uncertainty
#
# Run Monte Carlo scenarios to estimate uncertainty and preparedness effects.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## Monte Carlo uncertainty
#
# Sample weights around baseline assumptions and rerun risk scores. Compare baseline, improved screening, conflict disruption, mining surge, and deforestation/displacement scenarios.

# %%
from cberm.stochastic import monte_carlo_scores
scenarios = load_yaml(paths.root / "configs/scenarios.yml")
# mc = monte_carlo_scores(features, weights["combined_risk"], n_iterations=scenarios["monte_carlo"]["n_iterations"])
print(scenarios["monte_carlo"])
