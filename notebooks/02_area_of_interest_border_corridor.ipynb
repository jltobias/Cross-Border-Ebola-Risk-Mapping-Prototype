# %% [markdown]
# # Area of interest and border corridor
#
# Create the DRC-South Sudan/Uganda corridor AOI, border buffers, and reporting units.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## Build AOI
#
# Expected inputs: admin boundaries for South Sudan, DRC, and optionally Uganda. Recommended outputs: AOI polygon, border corridor buffer, reporting units.

# %%
# Example skeleton. Replace paths with confirmed layer_inventory entries.
# admin = gpd.read_file("GIS/admin_boundaries/admin0.gpkg").to_crs(config["project"]["default_crs"])
# focus = admin[admin["iso3"].isin(config["aoi"]["countries"])]
# aoi = focus.dissolve()
# corridor = aoi.buffer(config["aoi"]["border_buffer_km"] * 1000)
# corridor.to_file(paths.data_processed / "aoi_border_corridor.gpkg", driver="GPKG")
print("Fill in admin boundary paths after running notebook 01.")
