# %% [markdown]
# # Deterministic risk index
#
# Combine spillover, exposure, importation, and vulnerability into a transparent risk score.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## Deterministic weighted overlay
#
# Combine components using `configs/weights_baseline.yml`. Keep component scores separate so decision-makers can see why a location is high risk.

# %%
from cberm.risk import weighted_sum, combine_components, risk_tiers
weights = load_yaml(paths.root / "configs/weights_baseline.yml")
# features = pd.read_parquet(paths.data_processed / "facility_features_normalized.parquet")
# features["spillover_suitability"] = weighted_sum(features, weights["spillover_suitability"])
# features["human_exposure"] = weighted_sum(features, weights["human_exposure"])
# features["importation_pressure"] = weighted_sum(features, weights["importation_pressure"])
# features["facility_vulnerability"] = weighted_sum(features, weights["facility_vulnerability"])
# features["risk_score"] = combine_components(features, weights["combined_risk"])
# features["risk_tier"] = risk_tiers(features["risk_score"])
print(weights["combined_risk"])
