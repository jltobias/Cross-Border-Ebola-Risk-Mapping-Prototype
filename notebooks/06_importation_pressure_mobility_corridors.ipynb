# %% [markdown]
# # Importation pressure and mobility corridors
#
# Estimate outbreak pressure moving through road, border, river, market, and displacement corridors.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## Importation pressure
#
# Use recent affected health zones or case clusters as sources. Compute pressure to border points, settlements, facilities, or catchments using road-network travel time when available, with inverse-distance decay as a fallback.

# %%
from cberm.network import inverse_distance_pressure
# facilities = pd.read_csv(paths.data_processed / "facility_features.csv")
# sources = pd.read_csv(paths.data_processed / "outbreak_sources.csv")
# facilities["active_case_pressure"] = inverse_distance_pressure(facilities, sources)
print("Use network travel time when road data are ready; use inverse distance only as a transparent fallback.")
