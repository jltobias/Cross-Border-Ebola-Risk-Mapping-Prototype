# %% [markdown]
# # Repository orientation
#
# Review the modeling architecture, outputs, and data-governance assumptions.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## Modeling architecture
#
# The core score is a four-part ensemble: spillover suitability, human exposure, importation pressure, and facility vulnerability.

# %%
components = ["spillover_suitability", "human_exposure", "importation_pressure", "facility_vulnerability"]
components
