# %% [markdown]
# # Human-animal interface features
#
# Build forest edge, deforestation, mines/caves, orchards, population, roads, and conflict features.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## Feature ideas
#
# Create distance-to, density, edge, and overlap features for mines/caves, roosts, forest edges, orchards, buildings, roads, conflict events, rivers, and population.

# %%
# Example feature naming convention:
feature_columns = [
    "bat_roost_proximity",
    "forest_edge_density",
    "recent_deforestation",
    "mine_cave_karst_proximity",
    "orchard_fruit_tree_interface",
    "population_density",
    "road_accessibility",
    "conflict_displacement_pressure",
]
print(feature_columns)
