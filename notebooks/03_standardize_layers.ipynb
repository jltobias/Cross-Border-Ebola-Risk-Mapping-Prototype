# %% [markdown]
# # Layer standardization
#
# Standardize CRS, resolution, extent, nodata, and file naming across vector and raster layers.
#
# This notebook is part of the Cross-Border Ebola Risk Mapping workflow.

# %% [markdown]
# ## Setup
#
# Load project paths and configuration. Full geospatial notebooks require the conda environment in `environment.yml`.

# %%
from pathlib import Path
import pandas as pd
import numpy as np

try:
    import geopandas as gpd
    import rasterio
    import rioxarray as rxr
except Exception as exc:
    print("Full geospatial stack not available in this environment:", exc)

from cberm.config import ProjectPaths, load_yaml
paths = ProjectPaths.from_config()
paths.ensure()
config = load_yaml(paths.root / "configs/model_config.yml")
print(paths)

# %% [markdown]
# ## Standardization checklist
#
# 1. Reproject vectors to default CRS. 2. Clip to AOI. 3. Reproject rasters to template grid. 4. Save standardized outputs under `data/interim/standardized/`.

# %%
# Raster template example:
# template = rxr.open_rasterio("GIS/worldpop/population.tif", masked=True).squeeze()
# template = template.rio.reproject(config["project"]["default_crs"], resolution=config["project"]["grid_resolution_m"])
print("Create a template grid from population or AOI extent before processing covariates.")
